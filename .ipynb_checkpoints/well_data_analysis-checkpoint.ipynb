# %% [markdown]
# ##### *Import Libraries*

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# matplotlib.rcParams['figure.figsize'] = (20,10)
sns.set_theme(style="darkgrid")

# %% [markdown]
# ##### *Load Data Set*

# %%
well_data = pd.read_csv('./796_wells_lat_long.csv')
well_data.head()
# Out:
#     R_date  Latitude  Longitude  24/04/1995 12:00  24/04/2000 12:00  \
# 0  BA003_A     22.84      90.52             -0.34             -0.24
# 1  BA008_A     22.49      90.07              1.36              1.61
# 2  BA009_B     22.82      90.21             -0.21              0.14
# 3  BA010_A     22.83      90.28              0.81              1.41
# 4  BA011_A     22.96      90.52              0.25              1.83
#
#    25/04/2005 12:00  26/04/2010 12:00  27/04/2015 12:00
# 0             -0.68             -1.29             -0.81
# 1              1.21              1.48              1.66
# 2             -0.26               NaN             -0.18
# 3              1.21               NaN              1.31
# 4              0.80               NaN              0.90

# %%
# basic statistical description of the data
well_data.describe()
# Out:
#          Latitude   Longitude  24/04/1995 12:00  24/04/2000 12:00  \
# count  796.000000  796.000000        766.000000        756.000000
# mean    24.415264   89.674128         12.257115         13.341243
# std      0.999505    0.948122         16.262021         16.550045
# min     20.900000   88.120000        -14.990000        -26.620000
# 25%     23.697500   88.917500          2.160000          2.817500
# 50%     24.370000   89.510000          6.270000          7.345000
# 75%     25.020000   90.342500         14.235000         15.227500
# max     26.590000   92.340000         97.540000         97.700000
#
#        25/04/2005 12:00  26/04/2010 12:00  27/04/2015 12:00
# count        727.000000        557.000000        548.000000
# mean          12.594691         13.197774         14.615474
# std           16.567202         17.880531         18.545517
# min          -53.740000        -58.330000        -58.650000
# 25%            2.390000          1.960000          2.855000
# ...

# %% [markdown]
# ##### *Clean Data Set*

# %%
# setting column names for easy referencing
convenient_column_names = ['R_date','Lat','Lon','1995','2000','2005','2010','2015']
well_data.columns = convenient_column_names
well_data.describe()
# Out:
#               Lat         Lon        1995        2000        2005        2010  \
# count  796.000000  796.000000  766.000000  756.000000  727.000000  557.000000
# mean    24.415264   89.674128   12.257115   13.341243   12.594691   13.197774
# std      0.999505    0.948122   16.262021   16.550045   16.567202   17.880531
# min     20.900000   88.120000  -14.990000  -26.620000  -53.740000  -58.330000
# 25%     23.697500   88.917500    2.160000    2.817500    2.390000    1.960000
# 50%     24.370000   89.510000    6.270000    7.345000    6.770000    6.660000
# 75%     25.020000   90.342500   14.235000   15.227500   14.635000   16.250000
# max     26.590000   92.340000   97.540000   97.700000   97.820000   97.200000
#
#              2015
# count  548.000000
# mean    14.615474
# std     18.545517
# min    -58.650000
# 25%      2.855000
# 50%      7.345000
# 75%     20.970000
# max     97.330000

# %%
# finding out the max and minimum well water level values of the dataset
max_elevation = max(well_data.iloc[:,3:].max())
min_elevation = min(well_data.iloc[:,3:].min())

# %%
def classify(data,column,n):
    """
    adds a column to dataset by classifing based on a column.
    ---
    parameters
    data -- DataFrame -- dataframe
    column -- str -- column name
    n -- int -- number of segments. ie, n-1 ranges
    returns a DataFrame
    """
    range_points = np.linspace(min_elevation,max_elevation,n)
    criteria = [data[column].between(range_points[key-1],range_points[key]) for key,value in list(enumerate(range_points))[1:]]
    values = [f'{range_points[key-1]:.2f} ~ {range_points[key]:.2f}' for key,value in list(enumerate(range_points))[1:]]
    data['Well GWL Range'] = np.select(criteria, values, 0)
    
    return data

# making a function that returns a data set containing valid ie not null values of a certain year
def clean_data(column,df=well_data,n=6):
    columns_to_keep = ['Lat','Lon',column]
    out_df = df.copy().loc[:,columns_to_keep]
    out_df = out_df[out_df[column].notna()]
    out_df = gpd.GeoDataFrame(out_df, geometry=gpd.points_from_xy(out_df['Lon'], out_df['Lat']))
    out_df = classify(out_df,column,n)
    return out_df

# %%
# as an example, this is cleaned 1995 data
clean_data('1995')
# Out:
#        Lat    Lon  1995                   geometry Well GWL Range
# 0    22.84  90.52 -0.34  POINT (90.52000 22.84000)  -27.36 ~ 3.94
# 1    22.49  90.07  1.36  POINT (90.07000 22.49000)  -27.36 ~ 3.94
# 2    22.82  90.21 -0.21  POINT (90.21000 22.82000)  -27.36 ~ 3.94
# 3    22.83  90.28  0.81  POINT (90.28000 22.83000)  -27.36 ~ 3.94
# 4    22.96  90.52  0.25  POINT (90.52000 22.96000)  -27.36 ~ 3.94
# ..     ...    ...   ...                        ...            ...
# 791  24.28  89.84  7.32  POINT (89.84000 24.28000)   3.94 ~ 35.23
# 792  24.51  90.11  5.34  POINT (90.11000 24.51000)   3.94 ~ 35.23
# 793  24.31  89.97  6.99  POINT (89.97000 24.31000)   3.94 ~ 35.23
# 794  24.48  90.00  7.07  POINT (90.00000 24.48000)   3.94 ~ 35.23
# 795  24.29  89.89  6.72  POINT (89.89000 24.29000)   3.94 ~ 35.23
#
# [766 rows x 5 columns]

# %%
# storing cleaned data in a dictionary named df for easy future use
well_all = dict((x,clean_data(x)) for x in convenient_column_names[3:])
well_all
# Out:
# {'1995':        Lat    Lon  1995                   geometry Well GWL Range
#  0    22.84  90.52 -0.34  POINT (90.52000 22.84000)  -27.36 ~ 3.94
#  1    22.49  90.07  1.36  POINT (90.07000 22.49000)  -27.36 ~ 3.94
#  2    22.82  90.21 -0.21  POINT (90.21000 22.82000)  -27.36 ~ 3.94
#  3    22.83  90.28  0.81  POINT (90.28000 22.83000)  -27.36 ~ 3.94
#  4    22.96  90.52  0.25  POINT (90.52000 22.96000)  -27.36 ~ 3.94
#  ..     ...    ...   ...                        ...            ...
#  791  24.28  89.84  7.32  POINT (89.84000 24.28000)   3.94 ~ 35.23
#  792  24.51  90.11  5.34  POINT (90.11000 24.51000)   3.94 ~ 35.23
#  793  24.31  89.97  6.99  POINT (89.97000 24.31000)   3.94 ~ 35.23
#  794  24.48  90.00  7.07  POINT (90.00000 24.48000)   3.94 ~ 35.23
#  795  24.29  89.89  6.72  POINT (89.89000 24.29000)   3.94 ~ 35.23
#
#  [766 rows x 5 columns],
#  '2000':        Lat    Lon   2000                   geometry Well GWL Range
# ...

# %% [markdown]
# ---
#
# ### Load Bangladesh Shape file

# %%
# Plot map of Bangladesh
bd_map_ax = gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='white')

# %%
# this function plots the cleaned dataset on the map of Bangladesh
def generate_plot(column_name,geometry_col='geometry',df=well_all):
    country_ax = gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='white')
    da = df[column_name].copy()
    plt.figure(figsize=(5,9))
    country_ax = gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='white')
    ax = sns.scatterplot(data=da,x='Lon',y='Lat',hue='Well GWL Range', ax=country_ax, marker='+',legend=True)
    plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
    ax.set_title(column_name);
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    return ax

# %%
# Now plotting the five year cleaned data separately on map of Bangladesh
# Also saving an image of each plot 
# the figures are also saved in the dictionary `figures`
figures = {}
i=1
for x in convenient_column_names[3:]:
    ax = generate_plot(x)
    i+=1
#     fig = ax.get_figure()
    fig.savefig(x+'.jpeg', format='jpeg',dpi=150)
#     figures[x] = ax
plt.show()

# %%
len(well_all)
# Out:
# 5

# %%
# Plot side by side
def per_plot(i,year,axes,df=well_all):
    ld = False
    if i==4:
        ld=True
    axes[i].set_title(year)
    country_ax = gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='none', ax=axes[i])
    sea = sns.scatterplot(data=df[year],x='Lon',y='Lat',hue='Well GWL Range', ax=country_ax, marker='+', legend=ld)
    plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
    
def all_plot():
    fig, axes = plt.subplots(1,5, figsize=(20,8), sharey=True)
    fig.text(0.5,0.8,'Five Year Well GWL')
    i=0
    for year,df in well_all.items():
        per_plot(i,year,axes)
        i+=1
    
    return fig

        
fig = all_plot()  
fig.savefig('All_Plot.jpeg', format='jpeg',dpi=150)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
fig, axes = plt.subplots(1,1, figsize=(20,8), sharey=True)
country_ax = gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='none', ax=axes)
well_all['1995'].plot(column='Well GWL Range',legend=True, edgecolor='black', marker='+',ax=country_ax)
# Out:
# <AxesSubplot:>
