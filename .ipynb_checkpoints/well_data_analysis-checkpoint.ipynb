# %% [markdown]
# ## Study on Well Water Level Analysis of Bangladesh

# %% [markdown]
# ------
#
# #### *Import Libraries*
#
# -----

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# matplotlib.rcParams['figure.figsize'] = (20,10)
sns.set_theme(style="darkgrid")

# CONSTANTS
NUMBER_OF_SEGMENTS = 6 # ie five color ranges
COLORS = ['red','yellow','blue','green','orange'] # five color values
DPI = 500 # dpi of the plots that are to be saved

# %% [markdown]
# ---
# #### *Load Data Set*
# ---

# %%
well_data = pd.read_csv('./796_wells_lat_long.csv')
well_data.head()
# Out:
#     R_date  Latitude  Longitude  24/04/1995 12:00  24/04/2000 12:00  \
# 0  BA003_A     22.84      90.52             -0.34             -0.24
# 1  BA008_A     22.49      90.07              1.36              1.61
# 2  BA009_B     22.82      90.21             -0.21              0.14
# 3  BA010_A     22.83      90.28              0.81              1.41
# 4  BA011_A     22.96      90.52              0.25              1.83
#
#    25/04/2005 12:00  26/04/2010 12:00  27/04/2015 12:00
# 0             -0.68             -1.29             -0.81
# 1              1.21              1.48              1.66
# 2             -0.26               NaN             -0.18
# 3              1.21               NaN              1.31
# 4              0.80               NaN              0.90

# %%
# basic statistical description of the data
well_data.describe()
# Out:
#          Latitude   Longitude  24/04/1995 12:00  24/04/2000 12:00  \
# count  796.000000  796.000000        766.000000        756.000000
# mean    24.415264   89.674128         12.257115         13.341243
# std      0.999505    0.948122         16.262021         16.550045
# min     20.900000   88.120000        -14.990000        -26.620000
# 25%     23.697500   88.917500          2.160000          2.817500
# 50%     24.370000   89.510000          6.270000          7.345000
# 75%     25.020000   90.342500         14.235000         15.227500
# max     26.590000   92.340000         97.540000         97.700000
#
#        25/04/2005 12:00  26/04/2010 12:00  27/04/2015 12:00
# count        727.000000        557.000000        548.000000
# mean          12.594691         13.197774         14.615474
# std           16.567202         17.880531         18.545517
# min          -53.740000        -58.330000        -58.650000
# 25%            2.390000          1.960000          2.855000
# ...

# %% [markdown]
# ---
# #### *Clean and Process Data Set*
# ---

# %%
# setting column names for easy referencing
convenient_column_names = ['R_date','Lat','Lon','1995','2000','2005','2010','2015']
well_data.columns = convenient_column_names
well_data.describe()
# Out:
#               Lat         Lon        1995        2000        2005        2010  \
# count  796.000000  796.000000  766.000000  756.000000  727.000000  557.000000
# mean    24.415264   89.674128   12.257115   13.341243   12.594691   13.197774
# std      0.999505    0.948122   16.262021   16.550045   16.567202   17.880531
# min     20.900000   88.120000  -14.990000  -26.620000  -53.740000  -58.330000
# 25%     23.697500   88.917500    2.160000    2.817500    2.390000    1.960000
# 50%     24.370000   89.510000    6.270000    7.345000    6.770000    6.660000
# 75%     25.020000   90.342500   14.235000   15.227500   14.635000   16.250000
# max     26.590000   92.340000   97.540000   97.700000   97.820000   97.200000
#
#              2015
# count  548.000000
# mean    14.615474
# std     18.545517
# min    -58.650000
# 25%      2.855000
# 50%      7.345000
# 75%     20.970000
# max     97.330000

# %%
# finding out the max and minimum well water level values of the dataset
max_wl = max(well_data.iloc[:,3:].max())
min_wl = min(well_data.iloc[:,3:].min())

print(f'Maximum Water Level: {max_wl}\nMinimum Water Level: {min_wl}')
# Out:
# Maximum Water Level: 97.82
# Minimum Water Level: -58.65

# %%
# functions for cleaning and processing

def classify(data,column,colors=COLORS):
    """
    adds a column to dataset by classifing based on a column.
    also generates a color_pallet which will be used in plotting.
    ---
    parameters
    data -- DataFrame -- dataframe
    column -- str -- column name
    returns a DataFrame
    """
    global color_pallet
    max_elevation = max(well_data.iloc[:,3:].max())
    min_elevation = min(well_data.iloc[:,3:].min())
    range_points = np.linspace(min_elevation,max_elevation,NUMBER_OF_SEGMENTS)
    criteria = [data[column].between(range_points[key-1],range_points[key]) for key,value in list(enumerate(range_points))[1:]]
    values = [f'{range_points[key-1]:.2f} to {range_points[key]:.2f}' for key,value in list(enumerate(range_points))[1:]]
    color_pallet = dict((x,y) for x,y in zip(values,colors))
    data['Well GWL Range'] = np.select(criteria, values, 0)
    data['color'] = data['Well GWL Range'].map(color_pallet)
    return data

def clean_data(column,df=well_data):
    """
    returns a data set containing valid ie not null values of a certain year.
    ---
    parameters
    column -- str -- column name
    df -- DataFrame -- dataframe that is to be cleaned
    returns a DataFrame
    """
    columns_to_keep = ['Lat','Lon',column]
    out_df = df.copy().loc[:,columns_to_keep]
    out_df = out_df[out_df[column].notna()]
    out_df = gpd.GeoDataFrame(out_df, geometry=gpd.points_from_xy(out_df['Lon'], out_df['Lat']))
    out_df = classify(out_df,column)
    return out_df

# %%
# as an example, this is cleaned 1995 data
clean_data('1995').sample(n=5)
# Out:
#        Lat    Lon   1995                   geometry  Well GWL Range   color
# 565  26.10  89.22  41.37  POINT (89.22000 26.10000)  35.23 to 66.53   green
# 525  23.83  89.54   3.47  POINT (89.54000 23.83000)  -27.36 to 3.94  yellow
# 197  25.84  88.33  45.46  POINT (88.33000 25.84000)  35.23 to 66.53   green
# 369  22.83  89.21  -0.79  POINT (89.21000 22.83000)  -27.36 to 3.94  yellow
# 377  22.84  89.09  -1.84  POINT (89.09000 22.84000)  -27.36 to 3.94  yellow

# %%
# storing cleaned data in a dictionary named `well_all` for easy future use
well_all = dict((x,clean_data(x)) for x in convenient_column_names[3:])

# here is a brief priview(random three rows each year) of this `well_all` dataframe
list(map(lambda x:print(f'key: {x}\nvalue privew:\n{well_all[x].sample(3)}\n---'),well_all));
# Out:
# key: 1995
# value privew:
#        Lat    Lon  1995                   geometry  Well GWL Range   color
# 385  23.91  89.23  4.48  POINT (89.23000 23.91000)   3.94 to 35.23    blue
# 524  23.93  89.52  3.31  POINT (89.52000 23.93000)  -27.36 to 3.94  yellow
# 117  23.87  90.31  2.82  POINT (90.31000 23.87000)  -27.36 to 3.94  yellow
# ---
# key: 2000
# value privew:
#        Lat    Lon   2000                   geometry  Well GWL Range   color
# 235  25.93  88.17  32.11  POINT (88.17000 25.93000)   3.94 to 35.23    blue
# 548  22.08  89.94  -0.06  POINT (89.94000 22.08000)  -27.36 to 3.94  yellow
# 333  23.24  89.17   1.60  POINT (89.17000 23.24000)  -27.36 to 3.94  yellow
# ---
# key: 2005
# value privew:
#        Lat    Lon   2005                   geometry  Well GWL Range   color
# 264  23.30  90.38   1.43  POINT (90.38000 23.30000)  -27.36 to 3.94  yellow
# 317  24.76  89.97  11.97  POINT (89.97000 24.76000)   3.94 to 35.23    blue
# ...

# %% [markdown]
# ---
# ### Load Bangladesh Shape file
# ---

# %%
# Load and priview Bangladesh shape file
gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='white');

# %% [markdown]
# ---
# ### *Plotting*
# ---

# %%
# this function plots the cleaned dataset on the map of Bangladesh without ground water classification
def generate_plot(column_name,ax,geometry_col='geometry',df=well_all):
    '''
    plots well data by hue of Ground water level data of passed data set
    '''
    da = df[column_name].copy()
    gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='white', ax=ax)
    sns.scatterplot(data=da,x='Lon',y='Lat',hue='Well GWL Range', ax=ax, marker='+',legend=True)
    plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
    ax.set_title(column_name);
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')

# %% [markdown]
# - ### *Plot one after one*
#     without constatnt color classification

# %%
# Now plotting the five year cleaned data separately on map of Bangladesh without ground water classification
# Also saving an image of each plot 

for year in well_all.keys():
    fig,axes = plt.subplots(1,1,figsize=(5,9))
    generate_plot(year,axes)
    fig.savefig(year+'.jpeg', format='jpeg', dpi=DPI)
plt.show()

# %% [markdown]
# <!--
# # Plot side by side
# def per_plot(i,year,axes,df=well_all):
#     ld = True
# #     if i==4:
# #         ld=True
#     axes[i].set_title(year)
#     country_ax = gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='none', ax=axes[i])
#     sea = sns.scatterplot(data=df[year],x='Lon',y='Lat',hue='Well GWL Range', ax=country_ax, marker='+', legend=True)
#     plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
#
# def all_plot():
#     fig, axes = plt.subplots(1,5, figsize=(20,8), sharey=True)
#     fig.text(0.5,0.8,'Five Year Well GWL')
#     i=0
#     for year,df in well_all.items():
#         per_plot(i,year,axes)
#         i+=1
#
#     return fig
#
#
# fig = all_plot()
# fig.savefig('All_Plot.jpeg', format='jpeg',dpi=150)
# -->

# %% [markdown]
# <!--
# fig, axes = plt.subplots(1,5, figsize=(20,8), sharey=True)
# for i,key in enumerate(well_all.keys()):
#     country_ax = gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='none', ax=axes[i])
#     well_all[key].plot(column='Well GWL Range', edgecolor='black', marker='+',ax=country_ax, legend=True)
#     axes[i].set_title(key)
# -->

# %% [markdown]
# - ### *Plot side by side*
#     with constatnt color classification

# %%
# Now plotting the five year cleaned data separately on map of Bangladesh with ground water classification
# Also saving an image of the plot 
fig, axes = plt.subplots(1,5, figsize=(16,9), sharey=True)
for i,key in enumerate(well_all.keys()):
    df = well_all[key]
    gpd.read_file('./Bangladesh.shp').plot(edgecolor='black', color='none', ax=axes[i])
    size=81
    for j, dff in df.groupby('Well GWL Range'):
        axes[i].scatter(dff['Lon'], dff['Lat'], c=dff['color'], marker='+',edgecolor='black', label=j, s=100)
        axes[i].set_title(key)
#         axes[i].set_xlabel('Longitude')
#         axes[i].set_ylabel('Latitude')
        axes[i].legend(loc='center',bbox_to_anchor=(0.5, -0.35))
# fig.legend()
fig.text(s='Change in Ground Water Elevation of Well', x=0.40, y=0.80,fontsize=16)
# fig.suptitle('Change in Ground Water Elevation of Well')
fig.savefig('All_Plot.jpeg', format='jpeg',dpi=DPI)

# %%
color_pallet
# Out:
# {'-58.65 to -27.36': 'red',
#  '-27.36 to 3.94': 'yellow',
#  '3.94 to 35.23': 'blue',
#  '35.23 to 66.53': 'green',
#  '66.53 to 97.82': 'orange'}
